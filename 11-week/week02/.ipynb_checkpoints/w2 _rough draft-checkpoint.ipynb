# %%
import os
import requests
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv()

api_key = os.getenv("FRED_API_KEY")

url = "https://api.stlouisfed.org/fred/series/observations"
cpi_yoy = 'CORESTICKM159SFRBATL'
params = {
    "series_id": cpi_yoy,
    "api_key": api_key,
    "file_type": "json"
}

response = requests.get(url, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
# 200 means its good

# %%
# Extract observations and create the table
data = response.json()
data.keys()
# Out:
# dict_keys(['realtime_start', 'realtime_end', 'observation_start', 'observation_end', 'units', 'output_type', 'file_type', 'order_by', 'sort_order', 'count', 'offset', 'limit', 'observations'])

# %%
data
# Out:
# {'realtime_start': '2026-09-11',
#  'realtime_end': '2026-09-11',
#  'observation_start': '1600-01-01',
#  'observation_end': '9999-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 705,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1967-12-01',
#    'value': '.'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-01-01',
#    'value': '3.65186106'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-02-01',
#    'value': '3.673819411'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-03-01',
#    'value': '4.142163975'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-04-01',
#    'value': '4.155828095'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-05-01',
#    'value': '4.088245437'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-06-01',
#    'value': '4.545569347'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-07-01',
#    'value': '4.753076334'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-08-01',
#    'value': '4.9466066'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-09-01',
#    'value': '4.948246979'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-10-01',
#    'value': '5.182592347'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-11-01',
#    'value': '5.399387944'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1968-12-01',
#    'value': '5.706347843'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-01-01',
#    'value': '5.746196961'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-02-01',
#    'value': '5.749956071'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-03-01',
#    'value': '6.125157849'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-04-01',
#    'value': '6.505620421'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-05-01',
#    'value': '6.780633974'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-06-01',
#    'value': '6.375966005'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-07-01',
#    'value': '6.389268621'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-08-01',
#    'value': '6.414746498'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-09-01',
#    'value': '6.834758299'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-10-01',
#    'value': '6.560106336'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-11-01',
#    'value': '6.437390535'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1969-12-01',
#    'value': '6.402163808'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-01-01',
#    'value': '6.592370014'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-02-01',
#    'value': '7.053805927'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-03-01',
#    'value': '6.993096123'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-04-01',
#    'value': '6.817838113'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-05-01',
#    'value': '6.947734731'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-06-01',
#    'value': '7.151974844'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-07-01',
#    'value': '7.00787567'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-08-01',
#    'value': '7.114872285'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-09-01',
#    'value': '7.081263039'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-10-01',
#    'value': '7.057638255'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-11-01',
#    'value': '7.327620064'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1970-12-01',
#    'value': '7.342681298'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-01-01',
#    'value': '7.014858012'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-02-01',
#    'value': '6.329604979'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-03-01',
#    'value': '5.50160847'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-04-01',
#    'value': '5.306250794'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-05-01',
#    'value': '5.060279237'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-06-01',
#    'value': '5.239199701'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-07-01',
#    'value': '5.165044197'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-08-01',
#    'value': '4.913620811'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-09-01',
#    'value': '4.672385308'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-10-01',
#    'value': '4.376576593'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-11-01',
#    'value': '3.953153899'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1971-12-01',
#    'value': '3.677258309'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '
},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-03-01',
#    'value': '5.19152475'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-04-01',
#    'value': '5.276985365'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-05-01',
#    'value': '5.166732439'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-06-01',
#    'value': '5.370697673'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-07-01',
#    'value': '5.516605952'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-08-01',
#    'value': '5.836270781'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-09-01',
#    'value': '5.930360317'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-10-01',
#    'value': '5.798506168'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-11-01',
#    'value': '5.683108196'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1990-12-01',
#    'value': '5.651092078'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-01-01',
#    'value': '5.815290409'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-02-01',
#    'value': '5.8623588'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-03-01',
#    'value': '5.474284579'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-04-01',
#    'value': '5.276160434'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-05-01',
#    'value': '5.222445891'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-06-01',
#    'value': '4.934653949'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-07-01',
#    'value': '4.713410392'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-08-01',
#    'value': '4.393094508'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-09-01',
#    'value': '4.443594793'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-10-01',
#    'value': '4.288991989'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-11-01',
#    'value': '4.34967757'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1991-12-01',
#    'value': '4.346967664'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-01-01',
#    'value': '4.052308746'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-02-01',
#    'value': '3.861765064'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-03-01',
#    'value': '3.975844252'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-04-01',
#    'value': '4.066438773'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-05-01',
#    'value': '3.926410529'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-06-01',
#    'value': '3.860188559'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-07-01',
#    'value': '3.769367667'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-08-01',
#    'value': '3.628120085'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-09-01',
#    'value': '3.349237754'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-10-01',
#    'value': '3.6359146'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-11-01',
#    'value': '3.629469745'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1992-12-01',
#    'value': '3.478262556'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-01-01',
#    'value': '3.528455109'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-02-01',
#    'value': '3.561853788'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-03-01',
#    'value': '3.334428143'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-04-01',
#    'value': '3.404237829'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-05-01',
#    'value': '3.532736691'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-06-01',
#    'value': '3.569326945'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-07-01',
#    'value': '3.422616714'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-08-01',
#    'value': '3.508810757'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-09-01',
#    'value': '3.642383692'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-10-01',
#    'value': '3.424737275'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-11-01',
#    'value': '3.436277096'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1993-12-01',
#    'value': '3.548475916'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-01-01',
#    'value': '3.375759896'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-02-01',
#    'value': '3.415920384'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-03-01',
#    'value': '3.570150943'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-04-01',
#    'value': '3.354397547'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-05-01',
#    'value': '3.225532887'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-06-01',
#    'value': '3.194738495'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-07-01',
#    'value': '3.233880147'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-08-01',
#    'value': '3.306714086'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-09-01',
#    'value': '3.254281644'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-10-01',
#    'value': '3.164264289'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-11-01',
#    'value': '3.128282179'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1994-12-01',
#    'value': '2.901446577'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-01-01',
#    'value': '3.144200833'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-02-01',
#    'value': '3.124100115'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-03-01',
#    'value': '3.167481169'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-04-01',
#    'value': '3.306684647'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-05-01',
#    'value': '3.355294523'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-06-01',
#    'value': '3.332283478'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-07-01',
#    'value': '3.386948974'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-08-01',
#    'value': '3.23814109'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-09-01',
#    'value': '3.351697522'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-10-01',
#    'value': '3.46411606'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-11-01',
#    'value': '3.37996065'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1995-12-01',
#    'value': '3.379829487'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-01-01',
#    'value': '3.277075064'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-02-01',
#    'value': '3.259936249'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-03-01',
#    'value': '3.134500987'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-04-01',
#    'value': '3.004778103'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-05-01',
#    'value': '3.047772222'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-06-01',
#    'value': '3.051784638'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-07-01',
#    'value': '3.087421545'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-08-01',
#    'value': '3.083473301'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-09-01',
#    'value': '3.063090207'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-10-01',
#    'value': '2.943741816'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-11-01',
#    'value': '2.980390413'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1996-12-01',
#    'value': '3.05642197'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-01-01',
#    'value': '2.91241515'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-02-01',
#    'value': '2.802464903'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-03-01',
#    'value': '2.854608076'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-04-01',
#    'value': '2.910920374'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-05-01',
#    'value': '2.870203143'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-06-01',
#    'value': '2.828445596'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-07-01',
#    'value': '2.752239262'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-08-01',
#    'value': '2.653670773'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-09-01',
#    'value': '2.544804261'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-10-01',
#    'value': '2.618900715'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-11-01',
#    'value': '2.548580799'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1997-12-01',
#    'value': '2.621535622'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-01-01',
#    'value': '2.673178027'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-02-01',
#    'value': '2.691552555'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-03-01',
#    'value': '2.672304266'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-04-01',
#    'value': '2.640497846'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-05-01',
#    'value': '2.611332031'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-06-01',
#    'value': '2.600204475'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-07-01',
#    'value': '2.603335947'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-08-01',
#    'value': '2.633982138'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-09-01',
#    'value': '2.594217982'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-10-01',
#    'value': '2.535056337'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-11-01',
#    'value': '2.523581703'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1998-12-01',
#    'value': '2.437823'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-01-01',
#    'value': '2.383116'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-02-01',
#    'value': '2.316234'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-03-01',
#    'value': '2.237507'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-04-01',
#    'value': '2.226592'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-05-01',
#    'value': '2.153318'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-06-01',
#    'value': '2.070264'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-07-01',
#    'value': '2.111144'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-08-01',
#    'value': '2.094839'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-09-01',
#    'value': '2.070746'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-10-01',
#    'value': '2.04962'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-11-01',
#    'value': '2.147821'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '1999-12-01',
#    'value': '2.167848'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-01-01',
#    'value': '2.335519'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-02-01',
#    'value': '2.379221'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-03-01',
#    'value': '2.483286'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-04-01',
#    'value': '2.409239'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-05-01',
#    'value': '2.558647'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-06-01',
#    'value': '2.701492'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-07-01',
#    'value': '2.71297'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-08-01',
#    'value': '2.874818'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-09-01',
#    'value': '2.897082'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2000-10-01',
# ...
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2015-07-01',
#    'value': '2.130475'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2015-08-01',
#    'value': '2.169207'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2015-09-01',
#    'value': '2.268536'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2015-10-01',
#    'value': '2.335492'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2015-11-01',
#    'value': '2.394625'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2015-12-01',
#    'value': '2.437497'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-01-01',
#    'value': '2.460879'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-02-01',
#    'value': '2.538253'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-03-01',
#    'value': '2.526214'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-04-01',
#    'value': '2.53143'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-05-01',
#    'value': '2.565678'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-06-01',
#    'value': '2.563629'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-07-01',
#    'value': '2.569655'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-08-01',
#    'value': '2.716347'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-09-01',
#    'value': '2.624799'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-10-01',
#    'value': '2.502268'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-11-01',
#    'value': '2.518564'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2016-12-01',
#    'value': '2.585286'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-01-01',
#    'value': '2.651739'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-02-01',
#    'value': '2.664566'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-03-01',
#    'value': '2.436586'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-04-01',
#    'value': '2.235672'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-05-01',
#    'value': '2.139634'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-06-01',
#    'value': '2.122109'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-07-01',
#    'value': '2.131777'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-08-01',
#    'value': '2.075047'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-09-01',
#    'value': '2.091354'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-10-01',
#    'value': '2.177581'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-11-01',
#    'value': '2.099803'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2017-12-01',
#    'value': '2.117186'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-01-01',
#    'value': '2.157823'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-02-01',
#    'value': '2.123101'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-03-01',
#    'value': '2.366926'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-04-01',
#    'value': '2.491592'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-05-01',
#    'value': '2.543212'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-06-01',
#    'value': '2.551897'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-07-01',
#    'value': '2.518753'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-08-01',
#    'value': '2.432443'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-09-01',
#    'value': '2.462881'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-10-01',
#    'value': '2.415236'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-11-01',
#    'value': '2.476418'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2018-12-01',
#    'value': '2.456173'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-01-01',
#    'value': '2.375054'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-02-01',
#    'value': '2.375943'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-03-01',
#    'value': '2.356946'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-04-01',
#    'value': '2.392773'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-05-01',
#    'value': '2.360903'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-06-01',
#    'value': '2.392597'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-07-01',
#    'value': '2.475923'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-08-01',
#    'value': '2.630398'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-09-01',
#    'value': '2.622934'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-10-01',
#    'value': '2.747596'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-11-01',
#    'value': '2.772021'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2019-12-01',
#    'value': '2.752609'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-01-01',
#    'value': '2.800205'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-02-01',
#    'value': '2.792299'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-03-01',
#    'value': '2.592275'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-04-01',
#    'value': '2.160688'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-05-01',
#    'value': '2.000025'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-06-01',
#    'value': '1.998261'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-07-01',
#    'value': '2.287039'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-08-01',
#    'value': '2.22202'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-09-01',
#    'value': '1.991587'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-10-01',
#    'value': '1.74961'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-11-01',
#    'value': '1.707378'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2020-12-01',
#    'value': '1.603908'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-01-01',
#    'value': '1.388291876'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-02-01',
#    'value': '1.418483272'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-03-01',
#    'value': '1.606143425'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-04-01',
#    'value': '2.223969877'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-05-01',
#    'value': '2.568259586'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-06-01',
#    'value': '2.563298288'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-07-01',
#    'value': '2.322197731'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-08-01',
#    'value': '2.318851441'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-09-01',
#    'value': '2.597319102'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-10-01',
#    'value': '3.012541263'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-11-01',
#    'value': '3.188771392'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2021-12-01',
#    'value': '3.45168647'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-01-01',
#    'value': '3.958436369'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-02-01',
#    'value': '4.279048254'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-03-01',
#    'value': '4.53801172'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-04-01',
#    'value': '4.705074108'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-05-01',
#    'value': '4.959736415'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-06-01',
#    'value': '5.396005585'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-07-01',
#    'value': '5.584768451'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-08-01',
#    'value': '5.936757527'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-09-01',
#    'value': '6.3309531'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-10-01',
#    'value': '6.310662886'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-11-01',
#    'value': '6.430141331'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2022-12-01',
#    'value': '6.544834898'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-01-01',
#    'value': '6.488563553'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-02-01',
#    'value': '6.527668526'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-03-01',
#    'value': '6.394209'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-04-01',
#    'value': '6.265662148'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-05-01',
#    'value': '5.978671526'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-06-01',
#    'value': '5.579747568'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-07-01',
#    'value': '5.394823057'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-08-01',
#    'value': '5.160383368'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-09-01',
#    'value': '4.94927892'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-10-01',
#    'value': '4.882671706'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-11-01',
#    'value': '4.696200109'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2023-12-01',
#    'value': '4.563945276'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-01-01',
#    'value': '4.605479434'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-02-01',
#    'value': '4.407590907'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-03-01',
#    'value': '4.513039611'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-04-01',
#    'value': '4.413239633'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-05-01',
#    'value': '4.31094549'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-06-01',
#    'value': '4.240748674'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-07-01',
#    'value': '4.182298584'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-08-01',
#    'value': '4.1117892'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-09-01',
#    'value': '4.011581697'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-10-01',
#    'value': '3.975247122'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-11-01',
#    'value': '3.890822722'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2024-12-01',
#    'value': '3.752907132'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-01-01',
#    'value': '3.624695912'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-02-01',
#    'value': '3.520917355'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-03-01',
#    'value': '3.265924267'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-04-01',
#    'value': '3.178169333'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-05-01',
#    'value': '3.167989734'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-06-01',
#    'value': '3.302508446'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-07-01',
#    'value': '3.427070021'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-08-01',
#    'value': '3.430945316'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-09-01',
#    'value': '3.322171495'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-10-01',
#    'value': '3.077827'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-11-01',
#    'value': '2.954815062'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2025-12-01',
#    'value': '3.006319158'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-01-01',
#    'value': '2.979750936'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-02-01',
#    'value': '2.903909284'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-03-01',
#    'value': '2.929321192'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-04-01',
#    'value': '3.03893235'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-05-01',
#    'value': '3.091256621'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-06-01',
#    'value': '2.806860184'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-07-01',
#    'value': '2.715835582'},
#   {'realtime_start': '2026-09-11',
#    'realtime_end': '2026-09-11',
#    'date': '2026-08-01',
#    'value': '2.700641247'}]}

# %%
cpi_table = pd.DataFrame(data["observations"])

# %%
cpi_table.head()
# Out:
#   realtime_start realtime_end        date        value
# 0     2026-09-11   2026-09-11  1967-12-01            .
# 1     2026-09-11   2026-09-11  1968-01-01   3.65186106
# 2     2026-09-11   2026-09-11  1968-02-01  3.673819411
# 3     2026-09-11   2026-09-11  1968-03-01  4.142163975
# 4     2026-09-11   2026-09-11  1968-04-01  4.155828095

# %%
cpi_table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   realtime_start  705 non-null    str
#  1   realtime_end    705 non-null    str
#  2   date            705 non-null    str
#  3   value           705 non-null    str
# dtypes: str(4)
# memory usage: 22.2 KB

# %%
# this shows that there are no null values, but I was able to see in my df that the first df['value'] was "."
# I will convert everything to the right dtype and try again.

# %%
# Drop first row because value is "."
cpi_table = cpi_table.drop(cpi_table.index[0])

# Convert columns
cpi_table["realtime_start"] = pd.to_datetime(cpi_table["realtime_start"])
cpi_table["realtime_end"] = pd.to_datetime(cpi_table["realtime_end"])
cpi_table["date"] = pd.to_datetime(cpi_table["date"])
cpi_table["value"] = pd.to_numeric(cpi_table["value"])

# %%
cpi_table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 704 entries, 1 to 704
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   realtime_start  704 non-null    datetime64[us]
#  1   realtime_end    704 non-null    datetime64[us]
#  2   date            704 non-null    datetime64[us]
#  3   value           704 non-null    float64
# dtypes: datetime64[us](3), float64(1)
# memory usage: 22.1 KB

# %%
# ok looks like there is no null data

# %%
cpi_table.describe()
# Out:
#             realtime_start         realtime_end                        date  \
# count                  704                  704                         704
# mean   2026-09-11 00:00:00  2026-09-11 00:00:00  1997-04-16 11:06:49.090909
# min    2026-09-11 00:00:00  2026-09-11 00:00:00         1968-01-01 00:00:00
# 25%    2026-09-11 00:00:00  2026-09-11 00:00:00         1982-08-24 06:00:00
# 50%    2026-09-11 00:00:00  2026-09-11 00:00:00         1997-04-16 00:00:00
# 75%    2026-09-11 00:00:00  2026-09-11 00:00:00         2011-12-08 18:00:00
# max    2026-09-11 00:00:00  2026-09-11 00:00:00         2026-08-01 00:00:00
# std                    NaN                  NaN                         NaN
#
#             value
# count  704.000000
# mean     4.293951
# min      0.663868
# 25%      2.476294
# 50%      3.350468
# 75%      5.112544
# max     15.774167
# std      2.646000

# %%
cpi_table
# Out:
#     realtime_start realtime_end       date     value
# 1       2026-09-11   2026-09-11 1968-01-01  3.651861
# 2       2026-09-11   2026-09-11 1968-02-01  3.673819
# 3       2026-09-11   2026-09-11 1968-03-01  4.142164
# 4       2026-09-11   2026-09-11 1968-04-01  4.155828
# 5       2026-09-11   2026-09-11 1968-05-01  4.088245
# ..             ...          ...        ...       ...
# 700     2026-09-11   2026-09-11 2026-04-01  3.038932
# 701     2026-09-11   2026-09-11 2026-05-01  3.091257
# 702     2026-09-11   2026-09-11 2026-06-01  2.806860
# 703     2026-09-11   2026-09-11 2026-07-01  2.715836
# 704     2026-09-11   2026-09-11 2026-08-01  2.700641
#
# [704 rows x 4 columns]

# %% [markdown]
# ## Vizualizations - Comparing cool down

# %%
# After a peak lets compare the speed of the cool-down

# %%
# lets view the whole dataset

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 2))

plt.plot(
    cpi_table["date"],
    cpi_table["value"]
)

plt.title("Sticky-Price Consumer Price Inflation Over Time")
plt.xlabel("Date")
plt.ylabel("Year-over-Year Inflation Rate (%)")
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

 # I found out the peak and through dates for inflation in each of my target cycles, I let the latest cycle play out longer
target_ranges = {
    "1970s": ("1975-04-01", "1976-12-01"),
    "1980s": ("1980-06-01", "1983-07-01"),
    "2020s": ("2022-09-01", "2026-06-01")
}

plt.figure(figsize=(10, 6))

for name, (start, end) in target_ranges.items():

    # Get only data inside this range
    period = cpi_table[
        (cpi_table["date"] >= start) &
        (cpi_table["date"] <= end)
    ].copy()

    # Standardized x-axis to start from 0 instead of the datetime
    period["month"] = range(len(period))

    plt.plot(period["month"], period["value"], label=name)

plt.xlabel("Months Since Peak")
plt.ylabel("Inflation Rate (%)")
plt.title("Inflation After Peak")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# - From this chart you can see inflation is the lowest it was in all three peaks
# - also that the cool-off is much more tame this time around, with around 33% cool off in 20 months vs 50% in the 70s and somewhere near 40% in the 80s
